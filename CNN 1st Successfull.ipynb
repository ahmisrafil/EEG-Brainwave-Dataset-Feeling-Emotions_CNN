# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import cv2
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import warnings
warnings.filterwarnings('ignore')
from sklearn.metrics import confusion_matrix, classification_report
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, BatchNormalization, Conv2D, Dense, Dropout, Flatten, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# %%
train_dataset_path = 'C:/Users/AHM ISRAFIL/Documents/ANACONDA/EEG Signal/images/train/'
validation_dataset_path = 'C:/Users/AHM ISRAFIL/Documents/ANACONDA/EEG Signal/images/test/'

# %%
IMG_WIDTH = 360
IMG_HEIGHT = 360
BATCH_SIZE = 32

# %%
train_datagen = ImageDataGenerator(rescale=1.0/255,
                                  zoom_range=0.2,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  fill_mode='nearest')
train_generator = train_datagen.flow_from_directory(train_dataset_path,
                                                   target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                   batch_size=BATCH_SIZE,
                                                   class_mode='categorical',
                                                   shuffle=True)
# Out:
# Found 1704 images belonging to 3 classes.

# %%
validation_datagen = ImageDataGenerator(rescale=1.0/255)
validation_generator = validation_datagen.flow_from_directory(validation_dataset_path,
                                                             target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                             batch_size=BATCH_SIZE,
                                                             class_mode='categorical',
                                                             shuffle=True)
# Out:
# Found 428 images belonging to 3 classes.

# %%
labels = {value: key for key, value in train_generator.class_indices.items()}
print("Label Mappings for classes present in the training and validation datasets\n")
for key, value in labels.items():
    print(f"{key} : {value}")
# Out:
# Label Mappings for classes present in the training and validation datasets
#
# 0 : NEGATIVE
# 1 : NEUTRAL
# 2 : POSITIVE

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(15, 12))
idx = 0

for i in range(2):
    for j in range(5):
        label = labels[np.argmax(train_generator[0][1][idx])]
        ax[i, j].set_title(f"{label}")
        ax[i, j].imshow(train_generator[0][0][idx][:, :, :])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Sample Training Images", fontsize=21)
plt.show()

# %%
def create_model():
    model = Sequential([
        Conv2D(filters=128, kernel_size=(5, 5), padding='valid', input_shape=(IMG_WIDTH, IMG_HEIGHT, 3)),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        BatchNormalization(),
        
        Conv2D(filters=64, kernel_size=(3, 3), padding='valid', kernel_regularizer=l2(0.00005)),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        BatchNormalization(),
        
        Conv2D(filters=32, kernel_size=(3, 3), padding='valid', kernel_regularizer=l2(0.00005)),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        BatchNormalization(),
        
        Flatten(),
        
        Dense(units=256, activation='relu'),
        Dropout(0.5),
        Dense(units=3, activation='softmax')
    ])
    
    return model

# %%
cnn_model = create_model()

# %%
print(cnn_model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 356, 356, 128)     9728
#
#  activation (Activation)     (None, 356, 356, 128)     0
#
#  max_pooling2d (MaxPooling2D  (None, 178, 178, 128)    0
#  )
#
#  batch_normalization (BatchN  (None, 178, 178, 128)    512
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 176, 176, 64)      73792
#
#  activation_1 (Activation)   (None, 176, 176, 64)      0
#
#  max_pooling2d_1 (MaxPooling  (None, 88, 88, 64)       0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 88, 88, 64)       256
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 86, 86, 32)        18464
#
#  activation_2 (Activation)   (None, 86, 86, 32)        0
#
#  max_pooling2d_2 (MaxPooling  (None, 43, 43, 32)       0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 43, 43, 32)       128
#  hNormalization)
#
#  flatten (Flatten)           (None, 59168)             0
#
#  dense (Dense)               (None, 256)               15147264
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 3)                 771
#
# =================================================================
# Total params: 15,250,915
# Trainable params: 15,250,467
# Non-trainable params: 448
# _________________________________________________________________
# None

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=np.sqrt(0.1), patience=5)

# %%
optimizer = Adam(learning_rate=0.001)

# %%
cnn_model.compile(optimizer=optimizer, loss=CategoricalCrossentropy(), metrics=['accuracy'])

# %%
history = cnn_model.fit(train_generator, epochs=50, validation_data=validation_generator,
                       verbose=2,
                       callbacks=[reduce_lr])
# Out:
# Epoch 1/50
# 54/54 - 1175s - loss: 6.6450 - accuracy: 0.4038 - val_loss: 16.6247 - val_accuracy: 0.3364 - lr: 0.0010 - 1175s/epoch - 22s/step
# Epoch 2/50
# 54/54 - 1139s - loss: 1.3364 - accuracy: 0.3791 - val_loss: 1.2278 - val_accuracy: 0.3318 - lr: 0.0010 - 1139s/epoch - 21s/step
# Epoch 3/50
# 54/54 - 1153s - loss: 1.1039 - accuracy: 0.3732 - val_loss: 1.0600 - val_accuracy: 0.4369 - lr: 0.0010 - 1153s/epoch - 21s/step
# Epoch 4/50
# 54/54 - 1105s - loss: 1.1130 - accuracy: 0.3574 - val_loss: 1.1052 - val_accuracy: 0.3388 - lr: 0.0010 - 1105s/epoch - 20s/step
# Epoch 5/50
# 54/54 - 1357s - loss: 1.1111 - accuracy: 0.4073 - val_loss: 1.1054 - val_accuracy: 0.3364 - lr: 0.0010 - 1357s/epoch - 25s/step
# Epoch 6/50
# 54/54 - 1413s - loss: 1.0907 - accuracy: 0.3862 - val_loss: 1.0968 - val_accuracy: 0.3645 - lr: 0.0010 - 1413s/epoch - 26s/step
# Epoch 7/50
# 54/54 - 1417s - loss: 1.0943 - accuracy: 0.3920 - val_loss: 1.0011 - val_accuracy: 0.6005 - lr: 0.0010 - 1417s/epoch - 26s/step
# Epoch 8/50
# 54/54 - 1437s - loss: 1.0610 - accuracy: 0.4255 - val_loss: 1.0478 - val_accuracy: 0.5210 - lr: 0.0010 - 1437s/epoch - 27s/step
# Epoch 9/50
# 54/54 - 1437s - loss: 1.0634 - accuracy: 0.4266 - val_loss: 1.1019 - val_accuracy: 0.3575 - lr: 0.0010 - 1437s/epoch - 27s/step
# Epoch 10/50
# 54/54 - 1252s - loss: 1.0784 - accuracy: 0.3908 - val_loss: 0.9544 - val_accuracy: 0.6262 - lr: 0.0010 - 1252s/epoch - 23s/step
# Epoch 11/50
# 54/54 - 1251s - loss: 1.0489 - accuracy: 0.4390 - val_loss: 0.9110 - val_accuracy: 0.5467 - lr: 0.0010 - 1251s/epoch - 23s/step
# Epoch 12/50
# 54/54 - 1417s - loss: 1.0634 - accuracy: 0.4396 - val_loss: 0.9202 - val_accuracy: 0.5584 - lr: 0.0010 - 1417s/epoch - 26s/step
# Epoch 13/50
# 54/54 - 1158s - loss: 1.0669 - accuracy: 0.4419 - val_loss: 1.1885 - val_accuracy: 0.3762 - lr: 0.0010 - 1158s/epoch - 21s/step
# Epoch 14/50
# 54/54 - 1084s - loss: 1.0588 - accuracy: 0.4331 - val_loss: 0.9918 - val_accuracy: 0.5841 - lr: 0.0010 - 1084s/epoch - 20s/step
# Epoch 15/50
# 54/54 - 1156s - loss: 1.0473 - accuracy: 0.4425 - val_loss: 0.8786 - val_accuracy: 0.6262 - lr: 0.0010 - 1156s/epoch - 21s/step
# Epoch 16/50
# 54/54 - 1144s - loss: 1.0425 - accuracy: 0.4413 - val_loss: 0.8992 - val_accuracy: 0.5607 - lr: 0.0010 - 1144s/epoch - 21s/step
# Epoch 17/50
# 54/54 - 1059s - loss: 1.0217 - accuracy: 0.4531 - val_loss: 0.8748 - val_accuracy: 0.6449 - lr: 0.0010 - 1059s/epoch - 20s/step
# Epoch 18/50
# 54/54 - 1443s - loss: 1.0399 - accuracy: 0.4366 - val_loss: 0.8663 - val_accuracy: 0.6355 - lr: 0.0010 - 1443s/epoch - 27s/step
# Epoch 19/50
# 54/54 - 1229s - loss: 1.0334 - accuracy: 0.4595 - val_loss: 0.9535 - val_accuracy: 0.5234 - lr: 0.0010 - 1229s/epoch - 23s/step
# Epoch 20/50
# 54/54 - 1148s - loss: 1.0317 - accuracy: 0.4648 - val_loss: 0.8517 - val_accuracy: 0.6472 - lr: 0.0010 - 1148s/epoch - 21s/step
# Epoch 21/50
# 54/54 - 1038s - loss: 1.0300 - accuracy: 0.4431 - val_loss: 1.4913 - val_accuracy: 0.3551 - lr: 0.0010 - 1038s/epoch - 19s/step
# Epoch 22/50
# 54/54 - 1173s - loss: 1.0506 - accuracy: 0.4401 - val_loss: 2.4996 - val_accuracy: 0.3318 - lr: 0.0010 - 1173s/epoch - 22s/step
# Epoch 23/50
# 54/54 - 1234s - loss: 1.0580 - accuracy: 0.4372 - val_loss: 0.9323 - val_accuracy: 0.5047 - lr: 0.0010 - 1234s/epoch - 23s/step
# Epoch 24/50
# 54/54 - 1155s - loss: 1.0605 - accuracy: 0.4525 - val_loss: 1.0309 - val_accuracy: 0.3972 - lr: 0.0010 - 1155s/epoch - 21s/step
# Epoch 25/50
# 54/54 - 1097s - loss: 1.0401 - accuracy: 0.4630 - val_loss: 0.8820 - val_accuracy: 0.6379 - lr: 0.0010 - 1097s/epoch - 20s/step
# Epoch 26/50
# 54/54 - 1159s - loss: 0.9984 - accuracy: 0.4800 - val_loss: 0.8771 - val_accuracy: 0.6542 - lr: 3.1623e-04 - 1159s/epoch - 21s/step
# Epoch 27/50
# 54/54 - 1190s - loss: 1.0053 - accuracy: 0.4783 - val_loss: 0.8526 - val_accuracy: 0.6495 - lr: 3.1623e-04 - 1190s/epoch - 22s/step
# Epoch 28/50
# 54/54 - 1026s - loss: 0.9963 - accuracy: 0.4842 - val_loss: 0.8704 - val_accuracy: 0.6262 - lr: 3.1623e-04 - 1026s/epoch - 19s/step
# Epoch 29/50
# 54/54 - 1130s - loss: 0.9809 - accuracy: 0.4994 - val_loss: 0.8459 - val_accuracy: 0.6098 - lr: 3.1623e-04 - 1130s/epoch - 21s/step
# Epoch 30/50
# 54/54 - 1411s - loss: 0.9922 - accuracy: 0.4777 - val_loss: 0.9348 - val_accuracy: 0.4930 - lr: 3.1623e-04 - 1411s/epoch - 26s/step
# Epoch 31/50
# 54/54 - 1408s - loss: 0.9977 - accuracy: 0.4812 - val_loss: 0.9655 - val_accuracy: 0.5000 - lr: 3.1623e-04 - 1408s/epoch - 26s/step
# Epoch 32/50
# 54/54 - 1170s - loss: 1.0033 - accuracy: 0.4748 - val_loss: 0.8720 - val_accuracy: 0.6682 - lr: 3.1623e-04 - 1170s/epoch - 22s/step
# Epoch 33/50
# 54/54 - 1185s - loss: 0.9899 - accuracy: 0.4818 - val_loss: 0.8386 - val_accuracy: 0.6285 - lr: 3.1623e-04 - 1185s/epoch - 22s/step
# Epoch 34/50
# 54/54 - 1385s - loss: 1.0035 - accuracy: 0.4871 - val_loss: 1.3064 - val_accuracy: 0.3902 - lr: 3.1623e-04 - 1385s/epoch - 26s/step
# Epoch 35/50
# 54/54 - 1165s - loss: 0.9877 - accuracy: 0.4894 - val_loss: 0.9850 - val_accuracy: 0.5327 - lr: 3.1623e-04 - 1165s/epoch - 22s/step
# Epoch 36/50
# 54/54 - 1219s - loss: 0.9913 - accuracy: 0.4777 - val_loss: 0.9076 - val_accuracy: 0.6262 - lr: 3.1623e-04 - 1219s/epoch - 23s/step
# Epoch 37/50
# 54/54 - 1153s - loss: 0.9955 - accuracy: 0.4736 - val_loss: 0.9417 - val_accuracy: 0.6285 - lr: 3.1623e-04 - 1153s/epoch - 21s/step
# Epoch 38/50
# 54/54 - 1109s - loss: 1.0122 - accuracy: 0.4783 - val_loss: 0.8953 - val_accuracy: 0.5654 - lr: 3.1623e-04 - 1109s/epoch - 21s/step
# Epoch 39/50
# 54/54 - 1190s - loss: 0.9873 - accuracy: 0.4865 - val_loss: 0.9541 - val_accuracy: 0.5000 - lr: 1.0000e-04 - 1190s/epoch - 22s/step
# Epoch 40/50
# 54/54 - 1249s - loss: 0.9761 - accuracy: 0.5012 - val_loss: 0.9402 - val_accuracy: 0.5280 - lr: 1.0000e-04 - 1249s/epoch - 23s/step
# Epoch 41/50
# 54/54 - 1092s - loss: 0.9814 - accuracy: 0.4918 - val_loss: 0.9381 - val_accuracy: 0.5210 - lr: 1.0000e-04 - 1092s/epoch - 20s/step
# Epoch 42/50
# 54/54 - 1206s - loss: 0.9763 - accuracy: 0.4965 - val_loss: 0.8453 - val_accuracy: 0.6659 - lr: 1.0000e-04 - 1206s/epoch - 22s/step
# Epoch 43/50
# 54/54 - 1102s - loss: 0.9749 - accuracy: 0.5035 - val_loss: 0.8463 - val_accuracy: 0.6729 - lr: 1.0000e-04 - 1102s/epoch - 20s/step
# Epoch 44/50
# 54/54 - 1120s - loss: 0.9734 - accuracy: 0.5100 - val_loss: 0.8486 - val_accuracy: 0.5678 - lr: 3.1623e-05 - 1120s/epoch - 21s/step
# Epoch 45/50
# 54/54 - 1056s - loss: 0.9573 - accuracy: 0.5059 - val_loss: 0.8470 - val_accuracy: 0.5678 - lr: 3.1623e-05 - 1056s/epoch - 20s/step
# Epoch 46/50
# 54/54 - 1103s - loss: 0.9590 - accuracy: 0.5129 - val_loss: 0.8223 - val_accuracy: 0.6215 - lr: 3.1623e-05 - 1103s/epoch - 20s/step
# Epoch 47/50
# 54/54 - 1115s - loss: 0.9637 - accuracy: 0.5153 - val_loss: 0.8192 - val_accuracy: 0.6355 - lr: 3.1623e-05 - 1115s/epoch - 21s/step
# Epoch 48/50
# 54/54 - 1162s - loss: 0.9643 - accuracy: 0.5123 - val_loss: 0.8345 - val_accuracy: 0.6729 - lr: 3.1623e-05 - 1162s/epoch - 22s/step
# Epoch 49/50
# 54/54 - 1180s - loss: 0.9651 - accuracy: 0.5053 - val_loss: 0.8256 - val_accuracy: 0.6659 - lr: 3.1623e-05 - 1180s/epoch - 22s/step
# Epoch 50/50
# 54/54 - 1229s - loss: 0.9809 - accuracy: 0.4941 - val_loss: 0.8655 - val_accuracy: 0.6612 - lr: 3.1623e-05 - 1229s/epoch - 23s/step

# %%
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

train_loss = history.history['loss']
val_loss = history.history['val_loss']

learning_rate = history.history['lr']

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 10))

ax[0].set_title('Training Accuracy vs. Epochs')
ax[0].plot(train_accuracy, 'o-', label='Train Accuracy')
ax[0].plot(val_accuracy, 'o-', label='Validation Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='best')

ax[1].set_title('Training/Validation Loss vs. Epochs')
ax[1].plot(train_loss, 'o-', label='Train Loss')
ax[1].plot(val_loss, 'o-', label='Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='best')

ax[2].set_title('Learning Rate vs. Epochs')
ax[2].plot(learning_rate, 'o-', label='Learning Rate')
ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].legend(loc='best')

plt.tight_layout()
plt.show()

# %%
test_dataset = 'C:/Users/AHM ISRAFIL/Documents/ANACONDA/EEG Signal/images/test/'

# %%
test_datagen = ImageDataGenerator(rescale=1.0/255)

test_generator = test_datagen.flow_from_directory(test_dataset,
                                                 shuffle=False,
                                                 batch_size=BATCH_SIZE,
                                                 target_size = (IMG_WIDTH, IMG_HEIGHT),
                                                 class_mode='categorical')
# Out:
# Found 428 images belonging to 3 classes.

# %%
predictions = cnn_model.predict(test_generator)
# Out:
# 14/14 [==============================] - 28s 2s/step

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        predicted_label = labels[np.argmax(predictions[idx])]
        ax[i, j].set_title(f"{predicted_label}")
        ax[i, j].imshow(test_generator[0][0][idx])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Test Dataset Predictions", fontsize=20)
plt.show()

# %%
print(f"Test Loss:     {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15660\1261379058.py in <module>
#       1 #print(f"Test Loss:     {test_loss}")
# ----> 2 print(f"Test Accuracy: {test_accuracy}")
#
# NameError: name 'test_accuracy' is not defined

# %%
y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes

# %%
cf_mtx = confusion_matrix(y_true, y_pred)

group_counts = ["{0:0.0f}".format(value) for value in cf_mtx.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_mtx.flatten()/np.sum(cf_mtx)]
box_labels = [f"{v1}\n({v2})" for v1, v2 in zip(group_counts, group_percentages)]
box_labels = np.asarray(box_labels).reshape(3, 3)

plt.figure(figsize = (12, 10))
sns.heatmap(cf_mtx, xticklabels=labels.values(), yticklabels=labels.values(),
           cmap="YlGnBu", fmt="", annot=box_labels)
plt.xlabel('Predicted Classes')
plt.ylabel('True Classes')
plt.show()

# %%
print(classification_report(y_true, y_pred, target_names=labels.values()))
# Out:
#               precision    recall  f1-score   support
#
#     NEGATIVE       0.82      0.97      0.89       142
#      NEUTRAL       0.56      0.99      0.72       144
#     POSITIVE       0.40      0.01      0.03       142
#
#     accuracy                           0.66       428
#    macro avg       0.59      0.66      0.54       428
# weighted avg       0.59      0.66      0.55       428

# %%
errors = (y_true - y_pred != 0)
y_true_errors = y_true[errors]
y_pred_errors = y_pred[errors]

# %%
test_images = test_generator.filenames
test_img = np.asarray(test_images)[errors]

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        idx = np.random.randint(0, len(test_img))
        true_index = y_true_errors[idx]
        true_label = labels[true_index]
        predicted_index = y_pred_errors[idx]
        predicted_label = labels[predicted_index]
        ax[i, j].set_title(f"True Label: {true_label} \n Predicted Label: {predicted_label}")
        img_path = os.path.join(test_dataset, test_img[idx])
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        ax[i, j].imshow(img)
        ax[i, j].axis("off")

plt.tight_layout()
plt.suptitle('Wrong Predictions made on test set', fontsize=20)
plt.show()
